# %%
print('Anish')
# Out:
# Anish

# %%
print(1e308)
# Out:
# 1e+308

# %%
print(1e309)
# Out:
# inf

# %% [markdown]
# // data types

# %%
#complex
print(2+3j)
# Out:
# (2+3j)

# %%
#list
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#set
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({'name':'Anish', 'gender':'Male', 'weight':62})
# Out:
# {'name': 'Anish', 'gender': 'Male', 'weight': 62}

# %% [markdown]
# 3. Variables

# %%
#static vs dynamic typing
#static vs dynamic binding
# stylish declaration techniques

# %%
name = 'Anish'
print(name)
# Out:
# Anish

# %%
a=7
b=6
print(a+b)
# Out:
# 13

# %% [markdown]
# Dynamic typing

# %%
a=5 # dynamic typing
int c=6; # Static typing

# %%
# dynamic binding
a=6
print(a)
a='anish'
print(a)
# Out:
# 6
# anish

# %%
a=1
b=2
c=3
print(a, b, c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %%
#static vs dynamic
input()
# Out:
# '123'

# %%
input('Apna naam bata')
# Out:
# 'Anish'

# %%
# take input from user and store them in a variable 
# add the two variable
# print the result
fnum=int(input('Enter the first number'))
snum=int(input('Enter the second number'))
result=fnum+snum
print(result)
print(type(fnum))
# python boolean ko numbers ke tarah treat karta hai , in a mathematical expresseion
# true=1
# false=0
# Out:
# 101
# <class 'int'>
